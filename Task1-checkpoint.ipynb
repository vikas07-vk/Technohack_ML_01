# %% [markdown]
# <div style="text-align: center; color: blue; font-size: 30px;">
#     <B>TASK 1</B>
# </div>

# %% [markdown]
# <div style="text-align: center; color: blue; font-size: 30px;">
#     <B>DATA PREPROCESSING </B>
# </div>

# %% [markdown]
#  <H3>Import Librarires</H3>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#loding dataset
df=pd.read_csv("matches.csv")
df
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # Data Exploration

# %%
#get dimensions
df.shape
# Out:
# (636, 18)

# %%
#column info, datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             627 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      635 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           629 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  631 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
#summary statistics
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
#first five rows
df.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
#first 10 rows
df.head(10)
# Out:
#    id  season       city       date                        team1  \
# 0   1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune   4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3   4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad   4/9/2017                Gujarat Lions
# 6   7    2017     Mumbai   4/9/2017        Kolkata Knight Riders
# 7   8    2017     Indore  4/10/2017  Royal Challengers Bangalore
# 8   9    2017       Pune  4/11/2017             Delhi Daredevils
# 9  10    2017     Mumbai  4/12/2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
#last five rows 
df.tail()
# Out:
#       id  season       city       date                team1  \
# 631  632    2016     Raipur  5/22/2016     Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016        Gujarat Lions
# 633  634    2016      Delhi  5/25/2016  Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016        Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
#last 10 rows
df.tail(10)
# Out:
#       id  season           city       date                  team1  \
# 626  627    2016         Kanpur  5/19/2016  Kolkata Knight Riders
# 627  628    2016         Raipur  5/20/2016    Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  5/21/2016        Kings XI Punjab
# 629  630    2016         Kanpur  5/21/2016         Mumbai Indians
# 630  631    2016        Kolkata  5/22/2016  Kolkata Knight Riders
# 631  632    2016         Raipur  5/22/2016       Delhi Daredevils
# 632  633    2016      Bangalore  5/24/2016          Gujarat Lions
# 633  634    2016          Delhi  5/25/2016    Sunrisers Hyderabad
# 634  635    2016          Delhi  5/27/2016          Gujarat Lions
# 635  636    2016      Bangalore  5/29/2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 626                Gujarat Lions                Gujarat Lions         field
# 627             Delhi Daredevils             Delhi Daredevils         field
# ...

# %%
# getting all columns in a detaset
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# tells datatype of columns 
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
# fetching rows and columns

# %%
df["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
df[["team1","team2","winner"]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.iloc[:,[4,5,6,9]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                      toss_winner  dl_applied
# 0    Royal Challengers Bangalore           0
# 1         Rising Pune Supergiant           0
# 2          Kolkata Knight Riders           0
# ...

# %%
df.iloc[1:3]
# Out:
#    id  season    city      date           team1                   team2  \
# 1   2    2017    Pune  4/6/2017  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  4/7/2017   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %% [markdown]
# # Handling Missing values

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 9
# date                 0
# team1                0
# team2                0
# toss_winner          1
# toss_decision        0
# result               0
# dl_applied           0
# winner               7
# win_by_runs          0
# win_by_wickets       0
# player_of_match      5
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df.notnull()
# Out:
#        id  season  city  date  team1  team2  toss_winner  toss_decision  \
# 0    True    True  True  True   True   True         True           True
# 1    True    True  True  True   True   True         True           True
# 2    True    True  True  True   True   True         True           True
# 3    True    True  True  True   True   True         True           True
# 4    True    True  True  True   True   True         True           True
# ..    ...     ...   ...   ...    ...    ...          ...            ...
# 631  True    True  True  True   True   True         True           True
# 632  True    True  True  True   True   True         True           True
# 633  True    True  True  True   True   True         True           True
# 634  True    True  True  True   True   True         True           True
# 635  True    True  True  True   True   True         True           True
#
#      result  dl_applied  winner  win_by_runs  win_by_wickets  player_of_match  \
# ...

# %%
df.notnull().sum()
# Out:
# id                 636
# season             636
# city               627
# date               636
# team1              636
# team2              636
# toss_winner        635
# toss_decision      636
# result             636
# dl_applied         636
# winner             629
# win_by_runs        636
# win_by_wickets     636
# player_of_match    631
# venue              636
# umpire1            635
# umpire2            635
# umpire3              0
# dtype: int64

# %%
#dropna
df.dropna(axis=1)
# Out:
#       id  season       date                        team1  \
# 0      1    2017   4/5/2017          Sunrisers Hyderabad
# 1      2    2017   4/6/2017               Mumbai Indians
# 2      3    2017   4/7/2017                Gujarat Lions
# 3      4    2017   4/8/2017       Rising Pune Supergiant
# 4      5    2017   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...                          ...
# 631  632    2016  5/22/2016             Delhi Daredevils
# 632  633    2016  5/24/2016                Gujarat Lions
# 633  634    2016  5/25/2016          Sunrisers Hyderabad
# 634  635    2016  5/27/2016                Gujarat Lions
# 635  636    2016  5/29/2016          Sunrisers Hyderabad
#
#                            team2 toss_decision  result  dl_applied  \
# 0    Royal Challengers Bangalore         field  normal           0
# 1         Rising Pune Supergiant         field  normal           0
# 2          Kolkata Knight Riders         field  normal           0
# ...

# %%
df.dropna(how="any")
df.dropna(thresh=1)
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df1=df.drop(columns=['umpire3']) #dropping empire3 as it contains all null values
df1
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df1.isnull().sum()
# Out:
# id                 0
# season             0
# city               9
# date               0
# team1              0
# team2              0
# toss_winner        1
# toss_decision      0
# result             0
# dl_applied         0
# winner             7
# win_by_runs        0
# win_by_wickets     0
# player_of_match    5
# venue              0
# umpire1            1
# umpire2            1
# dtype: int64

# %%
#fillna
df1.fillna(0)
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# drop duplicates
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Length: 636, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df_copy=df1.copy
df_copy()
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#plotting graph using matplotlib
import matplotlib as plt
df["winner"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
df["toss_decision"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='toss_decision'>

# %%
df["toss_decision"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#saved the cleaned dataset

# %%
df1.to_csv("cleanedmatches.csv",index= "false") #save the file in folder( as umprie3 is drop as new dataset is this)
df1
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df2=pd.read_csv("cleanedmatches.csv") #for verification file is created or not
df2
# Out:
#      Unnamed: 0   id  season       city       date  \
# 0             0    1    2017  Hyderabad   4/5/2017
# 1             1    2    2017       Pune   4/6/2017
# 2             2    3    2017     Rajkot   4/7/2017
# 3             3    4    2017     Indore   4/8/2017
# 4             4    5    2017  Bangalore   4/8/2017
# ..          ...  ...     ...        ...        ...
# 631         631  632    2016     Raipur  5/22/2016
# 632         632  633    2016  Bangalore  5/24/2016
# 633         633  634    2016      Delhi  5/25/2016
# 634         634  635    2016      Delhi  5/27/2016
# 635         635  636    2016  Bangalore  5/29/2016
#
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# ...

# %%
# Min-Max Normalization
normalized_columns = ['win_by_runs', 'win_by_wickets']
df2[normalized_columns] = (df2[normalized_columns] - df2[normalized_columns].min()) / \
                                   (df2[normalized_columns].max() - df2[normalized_columns].min())
normalized_columns
# Out:
# ['win_by_runs', 'win_by_wickets']

# %%
df2
# Out:
#      Unnamed: 0   id  season       city       date  \
# 0             0    1    2017  Hyderabad   4/5/2017
# 1             1    2    2017       Pune   4/6/2017
# 2             2    3    2017     Rajkot   4/7/2017
# 3             3    4    2017     Indore   4/8/2017
# 4             4    5    2017  Bangalore   4/8/2017
# ..          ...  ...     ...        ...        ...
# 631         631  632    2016     Raipur  5/22/2016
# 632         632  633    2016  Bangalore  5/24/2016
# 633         633  634    2016      Delhi  5/25/2016
# 634         634  635    2016      Delhi  5/27/2016
# 635         635  636    2016  Bangalore  5/29/2016
#
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# ...
